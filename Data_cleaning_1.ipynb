# %%
import numpy as np

# %%
import pandas as pd

# %%
import  matplotlib.pyplot as plt

# %%
#read dataset

Data=pd.read_csv("tmdb_5000_credits.csv")

# %%
#print Data

Data
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
#to print 1st 15 rows    (head)

Data.head(15)
# Out:
#     movie_id                                       title  \
# 0      19995                                      Avatar
# 1        285    Pirates of the Caribbean: At World's End
# 2     206647                                     Spectre
# 3      49026                       The Dark Knight Rises
# 4      49529                                 John Carter
# 5        559                                Spider-Man 3
# 6      38757                                     Tangled
# 7      99861                     Avengers: Age of Ultron
# 8        767      Harry Potter and the Half-Blood Prince
# 9     209112          Batman v Superman: Dawn of Justice
# 10      1452                            Superman Returns
# 11     10764                           Quantum of Solace
# 12        58  Pirates of the Caribbean: Dead Man's Chest
# 13     57201                             The Lone Ranger
# 14     49521                                Man of Steel
#
# ...

# %%
#to print row according to indexing                using "iloc"
Data.iloc[5:20]
# Out:
#     movie_id                                        title  \
# 5        559                                 Spider-Man 3
# 6      38757                                      Tangled
# 7      99861                      Avengers: Age of Ultron
# 8        767       Harry Potter and the Half-Blood Prince
# 9     209112           Batman v Superman: Dawn of Justice
# 10      1452                             Superman Returns
# 11     10764                            Quantum of Solace
# 12        58   Pirates of the Caribbean: Dead Man's Chest
# 13     57201                              The Lone Ranger
# 14     49521                                 Man of Steel
# 15      2454     The Chronicles of Narnia: Prince Caspian
# 16     24428                                 The Avengers
# 17      1865  Pirates of the Caribbean: On Stranger Tides
# 18     41154                               Men in Black 3
# 19    122917    The Hobbit: The Battle of the Five Armies
#
# ...

# %%
#to print last 20 rows
Data.tail(20)
# Out:
#       movie_id                         title  \
# 4783    226458                      Backmask
# 4784     24055               The Puffy Chair
# 4785    287625          Stories of Our Lives
# 4786     44990              Breaking Upwards
# 4787     86304      All Superheroes Must Die
# 4788       692                Pink Flamingos
# 4789     39851                         Clean
# 4790     13898                    The Circle
# 4791    157185                   Tin Can Man
# 4792     36095                          Cure
# 4793    182291                On The Downlow
# 4794    286939  Sanctuary: Quite a Conundrum
# 4795    124606                          Bang
# 4796     14337                        Primer
# 4797     67238                        Cavite
# 4798      9367                   El Mariachi
# 4799     72766                     Newlyweds
# 4800    231617     Signed, Sealed, Delivered
# 4801    126186              Shanghai Calling
# 4802     25975             My Date with Drew
#
# ...

# %%
#to print Datatype or non null values
 


Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
#to print statistical  data     (mean,mode,mediun)
Data.describe()
# Out:
#             movie_id
# count    4803.000000
# mean    57165.484281
# std     88694.614033
# min         5.000000
# 25%      9014.500000
# 50%     14629.000000
# 75%     58610.500000
# max    459488.000000

# %%
# to print random  5 rows 
Data.sample(10)
# Out:
#       movie_id                       title  \
# 1716      9398                   Zoolander
# 4195     43947        I Spit on Your Grave
# 2307      2757                 Adaptation.
# 1970     10358  Zack and Miri Make a Porno
# 2519     22556     The Yellow Handkerchief
# 4457       905               Pandora's Box
# 1370      8065                          21
# 1315     12508                   Rock Star
# 3175      9656             Black Christmas
# 1292      1257           Because I Said So
#
#                                                    cast  \
# 1716  [{"cast_id": 1, "character": "Derek Zoolander"...
# 4195  [{"cast_id": 2, "character": "Jennifer Hills",...
# 2307  [{"cast_id": 4, "character": "Charlie/Donald K...
# 1970  [{"cast_id": 3, "character": "Zack", "credit_i...
# 2519  [{"cast_id": 5, "character": "Brett Hanson", "...
# 4457  [{"cast_id": 7, "character": "Lulu", "credit_i...
# 1370  [{"cast_id": 1, "character": "Ben Campbell", "...
# ...

# %%
#ckeck missing value

Data.isnull().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64
